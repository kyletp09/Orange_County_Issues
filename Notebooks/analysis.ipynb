# %%
import pandas as pd

df = pd.read_pickle('/Users/kylepham/Projects/Orange_County_Issues/Datasets/df.pkl')

df = df.drop(df[df['Author'] == 'None'].index).reset_index(drop=True)
df['Text'] = df['Text'].map(lambda x: x.strip('Getting your Trinity Audio player ready...'))
#df['Text'] = df['Text'].map(lambda x: x.split('—')[1] if '—' in x else x)
df['Date'] = df['Date'].map(lambda x: x.split('T')[0])
df.head(40)

#with open('example.txt', 'w+') as f:
#    f.write(df['Text'][19])
# Out:
#                                                 Title        Date  \
# 0   Jon Coupal: What Sacramento could learn from ALEC  2025-12-18
# 1   Huntington Beach councilmember sues school boa...  2025-12-18
# 2   How Salt-N-Pepa rewrote the rules for women in...  2025-12-18
# 3    Walt Disney International? Gwen Stefani Airport?  2025-12-18
# 4   Experts share their top tips to save money thi...  2025-12-18
# 5   Trump’s word games can’t conceal the murderous...  2025-12-18
# 6   The best things we ate at Southern California ...  2025-12-18
# 7   New student loan rule could dissuade people fr...  2025-12-18
# 8   How to keep your indoor plants thriving during...  2025-12-18
# 9   US says price increases eased last month but d...  2025-12-18
# 10  Brian Walshe is sentenced to life in prison fo...  2025-12-18
# 11  Trump administration moves to cut off transgen...  2025-12-18
# 12  FACT FOCUS: Trump’s glowing account of progres...  2025-12-18
# ...
